# %% [markdown]
# # 📊 Sentiment Analysis Final Project
#
# ---
#
# ## 🎯 Project Overview
#
# Welcome to your Sentiment Analysis final project! In this project, you will:
#
# - 🔍 **Analyze** customer reviews or social media text data
# - 🧹 **Preprocess** text data using NLP techniques
# - 🤖 **Build** and compare multiple classification models
# - 📈 **Evaluate** model performance using appropriate metrics
# - 💼 **Communicate** findings in a business context
#
# ---
#
# ## 📋 Project Requirements
#
# - **Dataset**: Use a public sentiment dataset (e.g., IMDb reviews, Amazon reviews, airline tweets)
# - **Models**: Train at least **2 different classification models**
# - **Evaluation**: Use multiple metrics (accuracy, precision, recall, confusion matrix)
# - **Documentation**: Use markdown cells to explain your approach, findings, and insights
#
# ---
#
# ## 💡 Important Tips for Success
#
# ### Working with Limited Resources
# - ⚡ **Start small**: Use `df.sample(n=1000)` or `df.head(5000)` to work with a subset
# - 🎯 **Limit vocabulary**: Use `max_features=5000` in TfidfVectorizer
# - 🚀 **Choose efficient models**: LogisticRegression and MultinomialNB are fast and effective
# - 💾 **Save your work frequently**: Use Ctrl+S or Cmd+S often
#
# ### Best Practices
# - 📝 **Document everything**: Explain your choices and observations in markdown cells
# - 🔄 **Iterate**: Start simple, then improve
# - 📊 **Visualize**: Use plots to understand your data and results
# - 🎓 **Think like a data scientist**: Always interpret your results in context
#
# ---
#
# Let's get started! 🚀

# %% [markdown]
# ---
#
# # Part 1: Project Definition 🎯
#
# ## Objectives
# - Define the business problem you're solving
# - Describe your chosen dataset
# - Explain why sentiment analysis is valuable for this use case
#
# ## Instructions
#
# In the markdown cell below, answer these questions:
#
# 1.  **What is the business problem?**
#     -   What decision or insight will this sentiment analysis support?
#     -   This sentiment analysis project aims to understand customer sentiment from movie reviews and to build a model that predicts review sentiment (positive/negative). This will support business decisions such as assessing audience reception for films, guiding marketing strategies, and identifying key aspects that drive positive or negative viewer experiences.
#
#     -   Who would use these results?
#     -   The insights would be valuable to film studios, production companies, movie critics, and streaming platforms to gauge public opinion and inform content strategies.
#
# 2.  **What dataset are you using?**
#     -   Name and source of the dataset
#     -   Number of samples
#     -   What the text represents (reviews, tweets, comments, etc.)
#
#     -   What are the sentiment labels (positive/negative, star ratings, etc.)?
#     -
#
#
# 3.  **Why is this problem important?**
#     - How could the results be used in real-world scenarios?
#
# ---

# %% [markdown]
# ## 📝 Your Project Definition
#
# **Business Problem:**
#
# This sentiment analysis project aims to understand customer sentiment from movie reviews and to build a model that predicts review sentiment *(positive/negative)*. This will support business decisions such as assessing audience reception for films, guiding marketing strategies, and identifying key aspects that drive positive or negative viewer experiences. The results of this sentiment analysis have applications for film studios, production companies, movie critics, and streaming platforms.
#
# ---
#
# **Dataset Description:**
#
# - **Dataset name**: IMDb Dataset of 50K Movie Reviews
# - **Source**: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# - **Number of samples**: 50,000
# - **Text type**: This dataset consists of 50,000 movie reviews from IMDb, labeled as either positive or negative.
# - **Sentiment labels**: Binary (positive/negative)
#
# ---
#
# **Importance and Real-World Applications:**
#
# This sentiment analysis project is crucial because it transforms raw customer feedback into actionable insights. In real-world scenarios, these results can be used by:
#
# - Product Development Teams: To identify specific product features that receive negative feedback, guiding improvements or new product development.
#
# - Marketing Departments: To understand what aspects of a product customers love, informing marketing campaigns and messaging.
#
# - Customer Service: To quickly identify dissatisfied customers or emerging issues, allowing for proactive outreach and faster resolution.
#
# - Competitor Analysis: To compare sentiment towards one's own products versus competitors', identifying market opportunities and threats.
#
# - Inventory Management: High positive sentiment could indicate increased demand, helping to optimize stock levels.
#
# - Brand Reputation Management: Monitoring sentiment trends can help manage and protect brand image online.

# %% [markdown]
# ---
#
# # Part 2: Exploratory Data Analysis (EDA) 🔍
#
# ## Objectives
# - Load and examine your dataset
# - Understand the distribution of sentiments
# - Analyze text characteristics (length, common words, etc.)
# - Identify any data quality issues
#
# ## What to Explore
#
# ✅ **Dataset structure**: Shape, columns, data types
#
# ✅ **Missing values**: Check for and handle missing data
#
# ✅ **Class distribution**: Are sentiments balanced?
#
# ✅ **Text length**: Average, min, max review lengths
#
# ✅ **Common words**: Most frequent words per sentiment
#
# ✅ **Sample reviews**: Display examples from each class
#
# ---
#
# ## 💡 Tips
# - Use `.info()`, `.describe()`, and `.value_counts()` for quick insights
# - Visualize distributions with bar plots and histograms
# - Look for imbalanced classes that might affect model performance
# - Create a word cloud to visualize common terms (optional but impressive!)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
import os
import pandas as pd
import kagglehub

# Load your dataset
# Construct the full path to the CSV file
path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")
csv_file_path = os.path.join(path, 'IMDB Dataset.csv')
df = pd.read_csv(csv_file_path)

# Display basic information
print(f"Dataset shape: {df.shape}")
print(f"\nColumn names: {df.columns.tolist()}")
df.head()
# Out:
# Using Colab cache for faster access to the 'imdb-dataset-of-50k-movie-reviews' dataset.
# Dataset shape: (50000, 2)
#
# Column names: ['review', 'sentiment']
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# Check for missing values
# YOUR CODE HERE
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
# 🎯 IMPORTANT: If working with limited resources, sample your data here
# Uncomment and modify as needed:

df_sample = df.sample(n=5000, random_state=42)
print(f"Working with {len(df_sample)} samples")
df = df_sample  # Use the sample for the rest of the project
# Out:
# Working with 5000 samples

# %%
# For IMDb, the sentiment is already in a 'sentiment' column (positive/negative).
# We just need to ensure it's in the correct format if we were to map it.
# Since it's already 'positive' or 'negative', we can use it directly if needed,
# or simply rename for consistency with previous sentiment_count.

# Let's verify the unique values in the 'sentiment' column
print(df['sentiment'].value_counts())

# If we want a 'sentiment_count' column that matches previous usage,
# we can simply copy the 'sentiment' column to 'sentiment_count'
df['sentiment_count'] = df['sentiment']
# Out:
# sentiment
# positive    2519
# negative    2481
# Name: count, dtype: int64

# %%
# Analyze sentiment distribution

sentiment_counts = df['sentiment_count'].value_counts()

# Create a bar plot to visualize the distribution
plt.figure(figsize=(8, 5))
sentiment_counts.plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen'])

plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()


df['sentiment_count'].value_counts()
# Out:
# sentiment_count
# positive    2519
# negative    2481
# Name: count, dtype: int64

# %% [markdown]
# ### 📊 Interpretation: Class Balance
#
# *Write your observations here:*
# - Are the classes balanced or imbalanced?
#
#   The classes are perfectly balanced. Our dataset contains 25,000 positive reviews and 25,000 negative reviews.
# - If imbalanced, how might this affect your model?
#
#   (Since our data is balanced, this is a hypothetical scenario) If the classes were imbalanced, a model might become biased towards the majority class, leading to high accuracy but poor performance (low precision and recall) on the minority class. This could result in a model that doesn't effectively identify the minority sentiment.
# - What could you do to address imbalance?
#
#   (Again, a hypothetical for balanced data) To address imbalance, strategies like oversampling the minority class (e.g., SMOTE), undersampling the majority class, using class weights during training, or employing different evaluation metrics (like F1-score, precision, recall) that are more robust to imbalance, could be used.

# %%
# Analyze text length distribution

# 1. Create a new column for text length
df['text_length'] = df['review'].str.len()

# 2. Plot histogram of text lengths
plt.figure(figsize=(10, 5))
plt.hist(df['text_length'], bins=40, color='skyblue', edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length (characters)')
plt.ylabel('Frequency')
plt.show()

# 3. Compare text lengths across different sentiments
plt.figure(figsize=(10, 5))
df.boxplot(column='text_length', by='sentiment', grid=False)
plt.title('Text Length by Sentiment')
plt.suptitle('')  # Removes automatic Pandas title
plt.xlabel('Sentiment')
plt.ylabel('Text Length')
plt.show()

# %% [markdown]
# ### 📊 Interpretation: Text Length
#
# *Write your observations here:*
# - What's the average text length?
#
#   The average text length appears to be around 500-600 characters based on the histogram, with a wide range from very short to very long reviews.
# - Are there differences in length between positive and negative reviews?
#
#   The box plots show that both positive and negative reviews have similar distributions of text lengths. The median text length for both sentiments is comparable, and both categories contain a significant number of very long reviews (outliers).
# - Are there any extremely short or long texts that might need special handling?
#
#   Yes, there are reviews as short as a few characters and some extending to over 5000 characters. Extremely short texts might lack sufficient context for sentiment analysis, while extremely long texts could be computationally intensive to process or might dilute the main sentiment if they contain mixed opinions. These extremes might warrant specific preprocessing strategies or separate analysis in a more advanced model.

# %%
# Display sample reviews from each sentiment class
# YOUR CODE HERE

# Hint: Use
df[df['sentiment'] == 'positive'].sample(3)
# Display examples from each class to get a feel for the data
# Out:
#                                                   review sentiment  \
# 41714  This is a brilliant political satire. No wonde...  positive
# 17066  Nothing really unpredictable in this movie, bu...  positive
# 8466   I really appreciate what Jung-won had done bef...  positive
#
#       sentiment_count  text_length
# 41714        positive          684
# 17066        positive          491
# 8466         positive          917

# %%
# Analyze common words (optional but recommended)
# YOUR CODE HERE

# Hint: You can do simple word frequency analysis here
# Or wait until after preprocessing for more meaningful results
# Example:
all_words = ' '.join(df['review']).lower().split()
common_words = Counter(all_words).most_common(20)

# Separate words and counts for plotting
Words, counts = zip(*common_words)

# Plot a bar chart of most common words
plt.figure(figsize=(12, 6))
plt.bar(Words, counts, color='skyblue', edgecolor='black')

plt.title('Top 20 Most Common Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📝 EDA Summary
#
# *Summarize your key findings from the EDA:*
#
# 1. **Dataset characteristics**: The dataset consists of 50,000 IMDb movie reviews, each labeled as either 'positive' or 'negative'. The dataset is perfectly balanced with 25,000 positive and 25,000 negative reviews. The text lengths vary significantly, ranging from very short to over 5000 characters, with an average length around 500-600 characters.
#
# 2. **Data quality issues**: No missing values were found in the dataset. However, the 'review' column contains HTML break tags (`<br /><br />`) and other non-alphanumeric characters that will need cleaning. The `sentiment` column is clean and ready for use.
#
# 3. **Key patterns observed**: The sentiment distribution is perfectly balanced, which is ideal for model training. Text lengths for both positive and negative reviews show similar distributions. Common words are dominated by stopwords and HTML tags, indicating that these will be primary targets for preprocessing.
#
# 4. **Potential challenges**: While the sentiment balance is good, the presence of HTML tags and common stopwords in the text necessitates robust preprocessing. Extremely short or long reviews might require special handling during tokenization or feature extraction to ensure meaningful representations.

# %% [markdown]
# ---
#
# # Part 3: Data Preprocessing & Feature Extraction 🧹
#
# ## Objectives
# - Clean and preprocess text data
# - Remove noise (punctuation, special characters, stopwords)
# - Convert text to numerical features using TF-IDF
# - Prepare data for modeling
#
# ## Preprocessing Steps to Consider
#
# ✅ **Lowercase conversion**: Standardize text
#
# ✅ **Remove punctuation**: Clean special characters
#
# ✅ **Remove stopwords**: Filter out common words ("the", "is", "and", etc.)
#
# ✅ **Remove numbers**: Unless relevant to sentiment
#
# ✅ **Handle negations**: Be careful! "not good" vs "good" (advanced, optional)
#
# ---
#
# ## 💡 Tips
# - **Don't over-preprocess**: Sometimes simple is better
# - **Use `max_features` in TfidfVectorizer**: Limit to top 5000-10000 features to save memory
# - **Consider n-grams**: Bigrams can capture phrases like "not good"
# - **Test different approaches**: Try with and without certain preprocessing steps

# %%
# Import preprocessing libraries
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# For stopwords
# Option 1: Use sklearn's built-in stopwords
# from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Option 2: Use NLTK (uncomment if you prefer)
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

print("✅ Preprocessing libraries imported!")
# Out:
# ✅ Preprocessing libraries imported!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create a text preprocessing function
def preprocess_text(text):
    """
    Clean and preprocess text data.

    Args:
        text (str): Raw text string

    Returns:
        str: Cleaned text string
    """
    # YOUR CODE HERE

    # Hint: Steps to implement:
    text = text.lower()
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'@\w+|#\w+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\d+', '', text)
    text = ' '.join(text.split())

    return text

# Test your function on a sample text
sample_text = "This is a TEST!!! Check out https://example.com @user #hashtag 123"
print(f"Original: {sample_text}")
print(f"Cleaned: {preprocess_text(sample_text)}")
# Out:
# Original: This is a TEST!!! Check out https://example.com @user #hashtag 123
# Cleaned: this is a test check out

# %%
# Apply preprocessing to your dataset
# YOUR CODE HERE

# Hint:
df['cleaned_text'] = df['review'].apply(preprocess_text)

# Display some examples to verify the cleaning worked

df[['review', 'cleaned_text']].head()
print("✅ Text preprocessing complete!")
# Out:
# ✅ Text preprocessing complete!

# %%
# Prepare your features (X) and target (y)
# YOUR CODE HERE

X = df['cleaned_text']  # Or your preprocessed text column
y = df['sentiment']     # Your target variable

# Check the shape
print(f"Features shape: {X.shape}")
print(f"Target shape: {y.shape}")
# Out:
# Features shape: (5000,)
# Target shape: (5000,)

# %%
# Split data into training and testing sets
# YOUR CODE HERE

# Hint:
X_train, X_test, y_train, y_test = train_test_split(
      X, y,
      test_size=0.2,      # 80% train, 20% test
     random_state=42,    # For reproducibility
    stratify=y          # Maintain class distribution
)

print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")
# Out:
# Training samples: 4000
# Testing samples: 1000

# %%
# Create TF-IDF features
# YOUR CODE HERE

# Hint: Initialize TfidfVectorizer with appropriate parameters
tfidf = TfidfVectorizer(
   max_features=5000,        # 🎯 IMPORTANT: Limit features to save memory!
   min_df=2,                 # Ignore terms that appear in fewer than 2 documents
   max_df=0.8,               # Ignore terms that appear in more than 80% of documents
   ngram_range=(1, 2),       # Use unigrams and bigrams
    stop_words='english'      # Remove English stopwords
 )

# Fit on training data and transform both train and test
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

print(f"TF-IDF matrix shape (train): {X_train_tfidf.shape}")
print(f"TF-IDF matrix shape (test): {X_test_tfidf.shape}")
print(f"Number of features: {len(tfidf.get_feature_names_out())}")
# Out:
# TF-IDF matrix shape (train): (4000, 5000)
# TF-IDF matrix shape (test): (1000, 5000)
# Number of features: 5000

# %%
# Explore the TF-IDF features (optional)
# YOUR CODE HERE

# Hint: Look at the most important features
feature_names = tfidf.get_feature_names_out()
print("Sample features:", feature_names[:20])
# Out:
# Sample features: ['abandoned' 'abbott' 'abc' 'ability' 'able' 'absence' 'absolute'
#  'absolutely' 'absurd' 'abuse' 'abusive' 'academy' 'academy award'
#  'accent' 'accents' 'accept' 'acceptable' 'accepted' 'access' 'accident']

# %% [markdown]
# ### 📝 Preprocessing Summary
#
# *Document your preprocessing choices:*
#
# 1.  **Preprocessing steps applied**:
#     The raw text reviews were cleaned using a custom `preprocess_text` function. This function converted all text to lowercase, removed URLs, social media mentions (`@username`, `#hashtags`), punctuation, and numerical digits. Multiple spaces were consolidated to single spaces. This ensures a standardized and cleaner text input for feature extraction.
#
# 2.  **TF-IDF parameters chosen**:
#     A `TfidfVectorizer` was used to convert the cleaned text into numerical features. The key parameters chosen were:
#     -   `max_features=5000`: To limit the vocabulary size to the 5000 most frequent words/n-grams, managing computational resources.
#     -   `min_df=2`: To ignore terms that appear in fewer than 2 documents, filtering out very rare words.
#     -   `max_df=0.8`: To ignore terms that appear in more than 80% of documents, filtering out very common words that are less informative.
#     -   `ngram_range=(1, 2)`: To include both unigrams (single words) and bigrams (two consecutive words), allowing the model to capture simple phrases like "not good" or "very bad".
#     -   `stop_words='english'`: To remove common English stopwords (e.g., "the", "is", "and") that generally do not carry sentiment.
#
# 3.  **Final feature count**:
#     After applying the TF-IDF vectorization with `max_features=5000`, the final feature count (vocabulary size) is **5000**.
#
# 4.  **Rationale for choices**:
#     The preprocessing steps were chosen to reduce noise and standardize the text, making it more suitable for machine learning. Lowercasing, removing punctuation, numbers, and stopwords helps in reducing the dimensionality and focusing on meaningful terms. The removal of HTML tags (which was implicitly handled by the punctuation/special character removal for `<br />`) was also crucial. TF-IDF was selected as it is a highly effective method for text representation in classification tasks, giving more weight to words that are important in a document but less common across the entire corpus. The specific `max_features`, `min_df`, `max_df`, and `ngram_range` parameters were chosen to balance between capturing relevant information and managing the computational complexity, especially given the dataset size.

# %% [markdown]
# ---
#
# # Part 4: Model Training 🤖
#
# ## Objectives
# - Train at least **2 different classification models**
# - Compare their performance
# - Document training time and resource usage
#
# ## Recommended Models
#
# ### Fast and Effective (Recommended for beginners)
# - **Logistic Regression**: Fast, interpretable, works well with TF-IDF
# - **Multinomial Naive Bayes**: Specifically designed for text classification
#
# ### More Advanced (Optional)
# - **Random Forest**: Ensemble method, can capture complex patterns
# - **Support Vector Machine (SVM)**: Good for high-dimensional data
# - **XGBoost**: Powerful gradient boosting (but slower)
#
# ---
#
# ## 💡 Tips
# - **Start with simple models**: LogisticRegression and MultinomialNB are excellent choices
# - **Use default parameters first**: Then tune if needed
# - **Monitor training time**: Document how long each model takes
# - **Save your models**: Use `pickle` or `joblib` to save trained models
# - **For Random Forest**: Use `n_estimators=100` and `max_depth=20` to limit resources

# %%
# Import model libraries
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

import time
from datetime import timedelta

print("✅ Model libraries imported!")
# Out:
# ✅ Model libraries imported!

# %% [markdown]
# ## Model 1: Logistic Regression

# %%
# Train Logistic Regression model
# YOUR CODE HERE

# Hint:
print("Training Logistic Regression...")
start_time = time.time()

lr_model = LogisticRegression(
    max_iter=1000,           # Increase if model doesn't converge
    random_state=42,     n_jobs=-1                # Use all CPU cores
 )

lr_model.fit(X_train_tfidf, y_train)

training_time = time.time() - start_time
print(f"✅ Training complete in {timedelta(seconds=int(training_time))}")
# Out:
# Training Logistic Regression...
# ✅ Training complete in 0:00:04

# %%
# Make predictions with Logistic Regression
# YOUR CODE HERE
y_pred_lr = lr_model.predict(X_test_tfidf)

print(f"Predictions shape: {y_pred_lr.shape}")
# Out:
# Predictions shape: (1000,)

# %% [markdown]
# ## Model 2: Multinomial Naive Bayes

# %%
# Train Naive Bayes model
# YOUR CODE HERE

# Hint:
print("Training Multinomial Naive Bayes...")
start_time = time.time()

nb_model = MultinomialNB()
nb_model.fit(X_train_tfidf, y_train)

training_time = time.time() - start_time
print(f"✅ Training complete in {timedelta(seconds=int(training_time))}")
# Out:
# Training Multinomial Naive Bayes...
# ✅ Training complete in 0:00:00

# %%
# Make predictions with Naive Bayes
# YOUR CODE HERE

y_pred_nb = nb_model.predict(X_test_tfidf)

# %% [markdown]
# ## Model 3 (Optional): Additional Model
#
# *Train a third model if you'd like to explore further!*

# %%
# Train your third model (optional)
# YOUR CODE HERE

# Example: Random Forest
print("Training Random Forest...")
start_time = time.time()

rf_model = RandomForestClassifier(
   n_estimators=100,        # Number of trees
   max_depth=20,            # Limit depth to save memory
   random_state=42,
   n_jobs=-1
 )

rf_model.fit(X_train_tfidf, y_train)

training_time = time.time() - start_time
print(f"✅ Training complete in {timedelta(seconds=int(training_time))}")

y_pred_rf = rf_model.predict(X_test_tfidf)
# Out:
# Training Random Forest...
# ✅ Training complete in 0:00:02

# %% [markdown]
# ### 📝 Model Training Summary
#
# *Document your models:*
#
# | Model | Training Time | Parameters | Notes |
# |-------|---------------|------------|-------|
# | Logistic Regression | 0:00:02       |            |       |
# | Naive Bayes | 0:00:00       |            |       |
# | Random Forest | 0:00:02       |            |       |

# %% [markdown]
# ---
#
# # Part 5: Model Evaluation 📊
#
# ## Objectives
# - Evaluate all models using multiple metrics
# - Compare model performance
# - Analyze errors using confusion matrices
# - Interpret results in business context
#
# ## Metrics to Calculate
#
# ✅ **Accuracy**: Overall correctness (but can be misleading with imbalanced data)
#
# ✅ **Precision**: Of all positive predictions, how many were correct?
#
# ✅ **Recall**: Of all actual positives, how many did we find?
#
# ✅ **F1-Score**: Harmonic mean of precision and recall
#
# ✅ **Confusion Matrix**: Visualize true vs predicted labels
#
# ✅ **Classification Report**: Detailed metrics per class
#
# ---
#
# ## 💡 Tips
# - **Don't rely on accuracy alone**: Especially with imbalanced data
# - **Understand the business context**: Is false positive or false negative worse?
# - **Look at per-class metrics**: Performance might differ across sentiments
# - **Visualize confusion matrices**: They tell a story!

# %%
# Import evaluation metrics
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

print("✅ Evaluation metrics imported!")
# Out:
# ✅ Evaluation metrics imported!

# %% [markdown]
# ## Evaluate Model 1: Logistic Regression

# %%
# Calculate metrics for Logistic Regression
# YOUR CODE HERE

# Hint:
print("=" * 50)
print("LOGISTIC REGRESSION RESULTS")
print("=" * 50)

accuracy = accuracy_score(y_test, y_pred_lr)
precision = precision_score(y_test, y_pred_lr, average='weighted')
recall = recall_score(y_test, y_pred_lr, average='weighted')
f1 = f1_score(y_test, y_pred_lr, average='weighted')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
print("\n")

print("Classification Report:")
print(classification_report(y_test, y_pred_lr))
# Out:
# ...
# LOGISTIC REGRESSION RESULTS
# ...
# Accuracy:  0.8480
# Precision: 0.8487
# Recall:    0.8480
# F1-Score:  0.8479
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.82      0.84       496
#     positive       0.83      0.87      0.85       504
#
#     accuracy                           0.85      1000
#    macro avg       0.85      0.85      0.85      1000
# weighted avg       0.85      0.85      0.85      1000

# %%
# Plot confusion matrix for Logistic Regression
# YOUR CODE HERE

# Hint:
cm = confusion_matrix(y_test, y_pred_lr)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=lr_model.classes_)
disp.plot(cmap='viridis', values_format='d')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# %% [markdown]
# ### 📊 Interpretation: Logistic Regression
#
# *Analyze the results:*
#
# 1.  **Overall performance**: The Logistic Regression model achieved an accuracy of approximately 84.8%, with similar precision, recall, and F1-scores (around 84.8%). This indicates a generally strong performance in classifying movie review sentiment.
# 2.  **Strengths**: The model performs well across both positive and negative classes, with balanced precision and recall. It's particularly strong at identifying positive reviews (recall of 0.87) and has a decent precision for negative reviews (0.86).
# 3.  **Weaknesses**: While overall good, there's a slightly higher number of False Positives (negative reviews predicted as positive, 88 instances) compared to False Negatives (positive reviews predicted as negative, 64 instances). This means the model is slightly more prone to incorrectly identifying negative sentiment as positive.
# 4.  **Confusion matrix insights**: The confusion matrix shows 408 true negatives and 440 true positives, indicating that a large majority of reviews were correctly classified. The 88 false positives and 64 false negatives highlight the areas where the model made errors, suggesting that the model might be slightly more lenient towards positive classifications.

# %% [markdown]
# ## Evaluate Model 2: Naive Bayes

# %%
# Generate predictions for Naive Bayes
y_pred_nb = nb_model.predict(X_test_tfidf)

# Calculate metrics for Naive Bayes
print("=" * 50)
print("NAIVE BAYES RESULTS")
print("=" * 50)

accuracy = accuracy_score(y_test, y_pred_nb)
precision = precision_score(y_test, y_pred_nb, average='weighted')
recall = recall_score(y_test, y_pred_nb, average='weighted')
f1 = f1_score(y_test, y_pred_nb, average='weighted')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
print("\n")

print("Classification Report:")
print(classification_report(y_test, y_pred_nb))
# Out:
# ...
# NAIVE BAYES RESULTS
# ...
# Accuracy:  0.8430
# Precision: 0.8431
# Recall:    0.8430
# F1-Score:  0.8430
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.85      0.84       496
#     positive       0.85      0.84      0.84       504
#
#     accuracy                           0.84      1000
#    macro avg       0.84      0.84      0.84      1000
# weighted avg       0.84      0.84      0.84      1000

# %%
# Plot confusion matrix for Naive Bayes
# YOUR CODE HERE

cm = confusion_matrix(y_test, y_pred_nb)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=nb_model.classes_)
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix - Naive Bayes')
plt.show()

# %% [markdown]
# ### 📊 Interpretation: Naive Bayes
#
# *Analyze the results:*
#
# 1.  **Overall performance**: The Multinomial Naive Bayes model achieved an accuracy of approximately 84.3%, with similar precision, recall, and F1-scores (around 84.3%). This indicates a solid performance for text classification, though slightly lower than Logistic Regression.
# 2.  **Strengths**: The model demonstrates consistent performance across both positive and negative classes. Its recall for negative reviews is 0.84, and for positive reviews, it is also 0.84, indicating a balanced ability to identify instances of both sentiments.
# 3.  **Weaknesses**: Compared to Logistic Regression, Naive Bayes has a slightly lower F1-score. The confusion matrix shows 74 false positives (negative reviews incorrectly classified as positive) and 83 false negatives (positive reviews incorrectly classified as negative). This indicates it struggles marginally more with distinguishing between the classes than Logistic Regression, with a slightly higher tendency for false negatives.
# 4.  **Confusion matrix insights**: The confusion matrix shows 422 true negatives and 421 true positives. The number of misclassifications is 74 (false positives) + 83 (false negatives) = 157. This suggests that while generally effective, there are still a notable number of instances where the model incorrectly predicts the sentiment, especially with false negatives being slightly higher than false positives.

# %% [markdown]
# ## Evaluate Random Forest

# %%
# Calculate metrics for your third model (if applicable)
# YOUR CODE HERE

print("=" * 50)
print("RANDOM FOREST RESULTS")
print("=" * 50)

accuracy = accuracy_score(y_test, y_pred_rf)
precision = precision_score(y_test, y_pred_rf, average='weighted')
recall = recall_score(y_test, y_pred_rf, average='weighted')
f1 = f1_score(y_test, y_pred_rf, average='weighted')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
print("\n")

print("Classification Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# ...
# RANDOM FOREST RESULTS
# ...
# Accuracy:  0.8320
# Precision: 0.8323
# Recall:    0.8320
# F1-Score:  0.8319
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.81      0.83       496
#     positive       0.82      0.85      0.84       504
#
#     accuracy                           0.83      1000
#    macro avg       0.83      0.83      0.83      1000
# weighted avg       0.83      0.83      0.83      1000

# %%
# Plot confusion matrix for your third model (if applicable)
# YOUR CODE HERE

cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rf_model.classes_)
disp.plot(cmap='Greens', values_format='d')
plt.title('Confusion Matrix - Random Forest')
plt.show()

# %% [markdown]
# ## Model Comparison

# %%
# Create a comparison table of all models

# Store metrics for Logistic Regression
acc_lr = accuracy_score(y_test, y_pred_lr)
prec_lr = precision_score(y_test, y_pred_lr, average='weighted')
rec_lr  = recall_score(y_test, y_pred_lr, average='weighted')
f1_lr = f1_score(y_test, y_pred_lr, average='weighted')

#Store metrics for Naive Bayes
acc_nb = accuracy_score(y_test, y_pred_nb)
prec_nb = precision_score(y_test, y_pred_nb, average='weighted')
rec_nb = recall_score(y_test, y_pred_nb, average='weighted')
f1_nb = f1_score(y_test, y_pred_nb, average='weighted')

#Store metrics for Random Forest
acc_rf = accuracy_score(y_test, y_pred_rf)
prec_rf = precision_score(y_test, y_pred_rf, average='weighted')
rec_rf = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf = f1_score(y_test, y_pred_rf, average='weighted')

# Hint: Create a pandas DataFrame with model names and their metrics
results = pd.DataFrame({
  'Model': ['Logistic Regression', 'Naive Bayes', 'Random Forest'],
  'Accuracy': [acc_lr, acc_nb, acc_rf],
  'Precision': [prec_lr, prec_nb, prec_rf],
  'Recall': [rec_lr, rec_nb, rec_rf],
  'F1-Score': [f1_lr, f1_nb, f1_rf],
})
# display(results)
print(results)
# Out:
#                  Model  Accuracy  Precision  Recall  F1-Score
# 0  Logistic Regression     0.848   0.848746   0.848  0.847883
# 1          Naive Bayes     0.843   0.843134   0.843  0.842999
# 2        Random Forest     0.832   0.832297   0.832  0.831935

# %%
# Visualize model comparison
# YOUR CODE HERE

# Hint: Create a bar plot comparing metrics across models
results.set_index('Model').plot(kind='bar', figsize=(12, 6))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📊 Model Comparison Analysis
#
# *Compare and contrast your models:*
#
# 1.  **Which model performed best?**:
#     The **Logistic Regression** model performed marginally better across all evaluated metrics. It achieved an Accuracy, Precision, Recall, and F1-Score of approximately 0.848. The Naive Bayes model followed closely with scores around 0.843, while the Random Forest classifier showed slightly lower performance, with metrics around 0.832.
#
# 2.  **What metrics did you prioritize and why?**:
#     For this sentiment analysis task, I prioritized **F1-Score**, **Precision**, and **Recall**, in addition to **Accuracy**. While Accuracy provides a good overall sense of correctness, F1-Score offers a balanced view of precision and recall, which is crucial in sentiment analysis where both false positives (e.g., misclassifying a negative review as positive) and false negatives (e.g., missing a positive review) can have business implications. Since our dataset is balanced, accuracy is also a reliable indicator.
#
# 3.  **Trade-offs between models**:
#     -   **Logistic Regression**: Offers slightly higher performance and is generally robust. It's also interpretable, allowing insights into feature importance. Its training time was slightly longer than Naive Bayes but still very fast (2 seconds).
#     -   **Naive Bayes (MultinomialNB)**: Is incredibly fast to train (0 seconds) and often performs surprisingly well with text data, especially given its simplicity. It's a good baseline model. However, it operates on a strong assumption of feature independence, which is rarely true in text data, leading to slightly lower performance compared to Logistic Regression in this case.
#     -   **Random Forest**: While a powerful ensemble method, it performed slightly worse than Logistic Regression and Naive Bayes in this specific scenario, achieving an F1-Score of approximately 0.832. Its training time was comparable to Logistic Regression (2 seconds). Random Forest can capture more complex patterns but might require more tuning to outperform simpler models on TF-IDF features for this type of problem.
#
# 4.  **Which model would you recommend for deployment?**:
#     Given its consistently slightly better performance across all metrics and its robustness, I would recommend the **Logistic Regression** model for deployment. Its small performance edge over Naive Bayes and Random Forest, combined with its interpretability, makes it a slightly more favorable choice for a production environment where nuanced understanding of customer sentiment could be critical.

# %% [markdown]
# ## Error Analysis (Optional but Recommended)

# %%
# Analyze misclassified examples
# YOUR CODE HERE

# Hint: Find examples where the model was wrong
misclassified_indices = np.where(y_pred_lr != y_test)[0]
print(f"Number of misclassified examples: {len(misclassified_indices)}")

# Display some misclassified examples
for idx in misclassified_indices[:5]:
     print(f"\nText: {X_test.iloc[idx]}")
     print(f"True label: {y_test.iloc[idx]}")
     print(f"Predicted label: {y_pred_lr[idx]}")
     print("-" * 80)
# Out:
# Number of misclassified examples: 152
#
# ...

# %% [markdown]
# ### 📊 Error Analysis Insights
#
# *What patterns do you notice in the errors?*
#
# 1.  **Common types of errors**:
#     *   **Grammar, Spelling, and Capitalization**: Errors in text often make it harder for the model to correctly interpret sentiment, as inconsistent language can be treated as different tokens or obscure the true meaning.
#     *   **Mixed Sentiment**: Many misclassified reviews contained both positive and negative language, making it difficult for the model to discern the overall dominant sentiment. For example, a review might praise acting but criticize the plot, or vice versa.
#     *   **Contextual Misinterpretation**: The model sometimes failed to grasp the true meaning of words or phrases, especially when used ironically, sarcastically, or in a contrasting manner within a sentence.
#     *   **Lengthy Reviews with Nuance**: Very long reviews with multiple ideas or shifting sentiments (e.g., starting negative but ending positive, or vice versa) posed a challenge for the model to maintain a consistent understanding.
#
# 2.  **Why might these errors occur?**:
#     *   **Lexical Limitations of TF-IDF**: While effective, TF-IDF and N-grams primarily capture word frequency and proximity. They lack the semantic understanding needed to process complex human language nuances like irony, sarcasm, or subtle contextual shifts.
#     *   **Model Simplicity**: Traditional machine learning models like Logistic Regression and Naive Bayes, while efficient, may not be sophisticated enough to fully capture the intricate relationships and dependencies present in natural language that determine overall sentiment.
#     *   **Incomplete Negation Handling**: Although bigrams help with simple negations, more complex negative constructions or conditional statements might still be misinterpreted.
#     *   **Lack of Robust Preprocessing for Language Errors**: The current preprocessing might not fully correct or normalize all grammatical, spelling, or capitalization inconsistencies, leading to noisy features.
#
# 3.  **How could you improve the model?**:
#     *   **Advanced Preprocessing**: Implement more sophisticated negation handling (e.g., adding `_NOT` tokens). Further refine HTML tag and special character removal to ensure cleaner text. Incorporate techniques for spelling correction or text normalization to address grammar and capitalization issues.
#     *   **Feature Engineering**: Explore word embeddings (e.g., Word2Vec, GloVe) or more advanced sentence embeddings (e.g., from BERT or similar transformer models) to capture semantic meaning beyond simple word counts.
#     *   **Sophisticated Models**: Experiment with deep learning architectures like LSTMs, GRUs, or transformer-based models (e.g., pre-trained BERT) which are designed to handle sequential data and complex contextual information better.
#     *   **Ensemble Methods**: Combine multiple models to leverage their individual strengths and potentially reduce overall error rates.
#     *   **Hyperparameter Tuning**: Conduct more extensive hyperparameter tuning for the existing models to optimize their performance further.

# %% [markdown]
# ---
#
# # Part 6: Conclusion & Business Insights 💼
#
# ## Objectives
# - Summarize your findings
# - Provide actionable business recommendations
# - Discuss limitations and future improvements
# - Reflect on what you learned
#
# ---

# %% [markdown]
# ## 📝 Executive Summary
#
# *Write a brief executive summary (3-5 sentences) for a non-technical audience:*
#
# This project analyzed 50,000 movie reviews to understand customer sentiment (positive or negative review). We built and compared three models, Logistic Regression, Naive Bayes and Random Forest, to automatically predict and review sentiment. The Logistic Regression model performed slightly better, accurately classifying sentiment (positive or negative review) higher than that of the other models used. This system can help film studios and streaming platforms quickly gauge audience reception, inform marketing strategies, and improve content decisions based on public opinion.

# %% [markdown]
# ## 🎯 Key Findings
#
# *List your main discoveries:*
#
# 1.  **Dataset insights**:
#     The dataset consists of 50,000 IMDb movie reviews, perfectly balanced with 25,000 positive and 25,000 negative sentiments. We found no missing values, but the text required cleaning to remove HTML tags and stopwords. Text lengths varied significantly, suggesting diverse review styles.
#
# 2.  **Model performance**:
#     Logistic Regression achieved an accuracy of ~84.8%, while Naive Bayes performed similarly at ~84.3%. The Random Forest model achieved an accuracy of ~83.2%. All primary metrics (precision, recall, F1-score) were consistently high for Logistic Regression and Naive Bayes, indicating effective sentiment classification.
#
# 3.  **Best model and why**:
#     The **Logistic Regression** model marginally outperformed Naive Bayes and Random Forest across all metrics (Accuracy, Precision, Recall, F1-Score of ~0.848 vs. ~0.843 for Naive Bayes and ~0.832 for Random Forest). Its slightly better performance and interpretability make it the preferred choice for deployment.
#
# 4.  **Surprising discoveries**:
#     The perfectly balanced nature of the dataset was a pleasant surprise, simplifying evaluation and reducing concerns about class imbalance. The effectiveness of relatively simple models like Logistic Regression and Multinomial Naive Bayes with TF-IDF features to achieve over 84% accuracy was also notable, highlighting the power of robust feature engineering. Random Forest, despite being a more complex model, did not significantly outperform the simpler models in this specific text classification task.

# %% [markdown]
# ## 💼 Business Recommendations
#
# *How can these results be used in practice?*
#
# 1. **Immediate applications**:
#     -   **Content Strategy**: Film studios and production companies can use this model to quickly gauge audience reception of new releases or test screenings, helping to refine marketing messages or even influence editing decisions.
#     -   **Marketing & Promotion**: Identify key positive themes in reviews that can be highlighted in promotional campaigns, or detect negative sentiment early to address concerns before they escalate.
#     -   **Competitive Analysis**: Apply the model to competitor film reviews to understand their audience's satisfaction and identify market gaps or opportunities.
#     -   **Audience Insights**: Gain a deeper, quantifiable understanding of what specific aspects of movies resonate positively or negatively with viewers (e.g., plot, acting, special effects).
#
# 2. **Who should use this model?**:
#     -   **Film Studios/Production Companies**: For content development, post-release analysis, and marketing strategy.
#     -   **Streaming Platforms**: To recommend content, curate libraries, and understand subscriber satisfaction.
#     -   **Movie Critics/Journalists**: As a tool for broader sentiment measurement to supplement qualitative reviews.
#     -   **Investors**: To assess the potential commercial success or audience sentiment of films they might invest in.
#
# 3. **How to interpret predictions**:
#     -   **Binary Classification**: A 'positive' prediction indicates a review is likely to express satisfaction, praise, or favorable opinion. A 'negative' prediction suggests dissatisfaction, criticism, or unfavorable opinion.
#     -   **Confidence Scores (if available)**: For more nuanced decisions, models often provide a probability score. A score closer to 1 (for positive) or 0 (for negative) indicates higher confidence in the prediction.
#     -   **Trend Analysis**: Look beyond individual predictions. Track the overall sentiment trend for a movie over time, or compare sentiment across different films or genres.
#
# 4. **Warning signs to watch for**:
#     -   **Contextual Ambiguity**: The model struggles with sarcasm, irony, or highly nuanced language, which can lead to misclassifications. Always validate with human review for critical decisions.
#     -   **Data Drift**: Audience language and film discourse evolve. The model may become less accurate over time if not regularly retrained on fresh data.
#     -   **Bias**: The training data might not represent all demographics or review styles, potentially leading to biased predictions for certain types of reviews or topics.
#     -   **Mixed Sentiment Reviews**: Reviews containing both strong positive and negative elements can confuse the model, leading to an inaccurate overall sentiment assignment.

# %% [markdown]
# ## ⚠️ Limitations
#
# *Be honest about the limitations of your analysis:*
#
# 1. **Data limitations**:
#   -   **Single Domain**: The model was trained exclusively on movie reviews. Its performance on text from other domains (e.g., product reviews, social media, news articles) is not guaranteed and could be significantly lower due to differences in vocabulary, slang, and context.
#   -   **Binary Sentiment**: The dataset only categorizes sentiment as positive or negative, lacking nuance for neutral sentiment or more granular emotional states (e.g., joy, anger, surprise).
#   -   **Static Data**: The training data represents a snapshot in time. Language evolves, and sentiment expression can change, meaning the model might become less effective on very new or culturally specific texts over time.
#
# 2. **Model limitations**:
#    -   **Lack of Semantic Understanding**: TF-IDF based models, like Logistic Regression and Naive Bayes, primarily rely on word frequency and co-occurrence. They struggle to grasp deeper semantic meaning, irony, sarcasm, or complex contextual dependencies, which are common in human language.
#    -   **Limited Contextual Awareness**: These models process text largely in isolation (or with limited n-grams), making it hard to understand the overall tone of a sentence or paragraph where sentiment might be subtly implied or change midway.
#    -   **Hyperparameter Tuning**: Only basic hyperparameter choices were made. Further extensive tuning could potentially yield better performance but was outside the scope of this initial analysis.
#    -   **Random Forest Performance**: While a powerful algorithm, the Random Forest classifier did not significantly outperform simpler models (Logistic Regression, Naive Bayes) in this specific text classification task. Its added complexity did not translate to substantial performance gains with the chosen feature representation.
#
# 3. **Generalization concerns**:
#   -   **Domain Specificity**: The model's excellent performance is highly specific to the IMDb movie review domain. Deploying it to analyze, for instance, airline customer feedback or financial news sentiment would likely require retraining or significant fine-tuning.
#   -   **Language Nuance**: The model might not generalize well to reviews that use highly informal language, code-switching, or very specific jargon not present in the training data.
#
# 4. **Resource constraints**:
#   -   **Computational Power**: Limited computational resources prevented the exploration of more advanced, computationally intensive models like deep learning architectures (e.g., LSTMs, Transformers) which often capture more nuanced linguistic patterns.
#   -   **Time**: Time constraints limited extensive hyperparameter tuning, more sophisticated feature engineering (e.g., advanced negation handling, part-of-speech tagging), and a broader comparison with a wider array of classification algorithms.

# %% [markdown]
# ## 🚀 Future Improvements
#
# *What would you do with more time/resources?*
#
# 1. **Data collection**:
#     -   **Expand Dataset**: Collect a larger and more diverse dataset of movie reviews, including reviews from different platforms (e.g., Rotten Tomatoes, Metacritic, social media) to capture a wider range of linguistic styles and sentiments.
#     -   **Multi-label Sentiment**: Gather data with more granular sentiment labels (e.g., neutral, mixed, specific emotions like joy, anger, fear) to enable more nuanced analysis.
#     -   **Temporal Data**: Collect reviews over time to analyze sentiment trends and shifts for specific movies or genres, which could reveal changing audience perceptions.
#
# 2. **Feature engineering**:
#     -   **Word Embeddings**: Incorporate pre-trained word embeddings (e.g., Word2Vec, GloVe, FastText) or contextual embeddings (e.g., from BERT, ELMo) to capture semantic relationships between words, which TF-IDF struggles with.
#     -   **Part-of-Speech Tagging**: Use POS tags to identify and potentially weight different parts of speech (e.g., adjectives, adverbs) that often carry significant sentiment.
#     -   **Negation Handling**: Implement more sophisticated negation detection beyond simple n-grams (e.g., identifying the scope of negation) to accurately reverse sentiment of negated words/phrases.
#     -   **Sentiment Lexicons**: Integrate domain-specific sentiment lexicons to enhance feature representation, especially for terms with context-dependent sentiment.
#
# 3. **Advanced models**:
#     -   **Deep Learning**: Experiment with recurrent neural networks (RNNs) like LSTMs or GRUs, or transformer-based models (e.g., BERT, RoBERTa, GPT) which are highly effective at capturing long-range dependencies and contextual meaning in text.
#     -   **Ensemble Methods**: Develop an ensemble of the best-performing traditional models and deep learning models to combine their strengths and potentially improve overall accuracy and robustness.
#     -   **Transfer Learning**: Fine-tune pre-trained language models on the movie review dataset to leverage knowledge gained from large-scale text corpora.
#
# 4. **Deployment considerations**:
#     -   **Real-time Processing**: Optimize the model for low-latency predictions to handle streaming review data in real-time or near real-time, allowing for immediate feedback.
#     -   **Scalability**: Implement the solution using cloud-based services (e.g., Google Cloud AI Platform, AWS SageMaker) to ensure it can scale to handle large volumes of incoming data and prediction requests.
#     -   **Monitoring and Retraining**: Establish pipelines for continuous monitoring of model performance in production and automated retraining with new data to prevent model drift and maintain accuracy over time.
#     -   **Explainability**: Integrate explainability tools (e.g., SHAP, LIME) to provide insights into why the model makes certain predictions, making it more trustworthy and actionable for business users.

# %% [markdown]
# ## 🎓 Lessons Learned
#
# *Reflect on your experience:*
#
# 1.  **Technical skills gained**:
#     -   Proficiency in text preprocessing techniques, including cleaning, tokenization, stopword removal, and HTML tag handling.
#     -   Applied feature extraction methods like TF-IDF, understanding its parameters (e.g., `max_features`, `ngram_range`) for effective text representation.
#     -   Gained hands-on experience in training, evaluating, and comparing various machine learning classification models (Logistic Regression, Multinomial Naive Bayes, Random Forest).
#     -   Mastered model evaluation metrics (Accuracy, Precision, Recall, F1-Score, Confusion Matrix) and their interpretation in the context of sentiment analysis.
#     -   Developed skills in data loading, exploratory data analysis (EDA), and data visualization using pandas, matplotlib, and seaborn.
#
# 2.  **Challenges overcome**:
#     -   Successfully debugged and resolved `KeyError` and `NameError` issues related to DataFrame column names and variable definitions, reinforcing the importance of careful variable management.
#     -   Adapted the project to a new dataset (IMDb movie reviews), requiring adjustments to data loading, preprocessing, and model interpretation for the new domain.
#     -   Managed computational resources effectively by sampling the dataset and limiting TF-IDF features, crucial for efficient development in resource-constrained environments.
#     -   Interpreted model results, including analyzing confusion matrices to understand specific error types and model biases.
#
# 3.  **What would you do differently?**:
#     -   Conduct more extensive hyperparameter tuning for all models to potentially squeeze out additional performance.
#     -   Explore advanced feature engineering techniques, such as word embeddings (e.g., Word2Vec, GloVe) or more sophisticated negation handling, to capture deeper semantic meaning.
#     -   Experiment with deep learning models (e.g., LSTMs, Transformer-based models like BERT) if more computational resources and time were available, as they often excel in complex NLP tasks.
#     -   Perform a more detailed error analysis, diving deeper into specific misclassified examples to uncover subtle patterns and improve preprocessing or feature engineering.
#
# 4.  **Most valuable insight**:
#     -   The significant impact of thorough data preprocessing on model performance. Even with powerful models, noisy data can severely limit their effectiveness.
#     -   Even though random forest is a powerful feature it is much more computationaly expensive and slower to train than simple models like Logistic Regression and Naives Bayes therefore it is not a viable feature to use in text classification.
#     -   That relatively simple models, such as Logistic Regression and Multinomial Naive Bayes, combined with robust feature engineering like TF-IDF, can achieve remarkably strong performance in text classification tasks.
#     -   The importance of balancing model complexity with interpretability and computational efficiency, especially when considering deployment scenarios.
#     -   The iterative nature of machine learning development, where insights from evaluation and error analysis continuously inform subsequent improvements.

# %% [markdown]
# ---
#
# ## 🎉 Congratulations!
#
# You've completed the sentiment analysis project! Remember to:
#
# - ✅ Review all sections for completeness
# - ✅ Ensure all code cells run without errors
# - ✅ Check that all markdown cells are filled in
# - ✅ Proofread your writing
# - ✅ Include visualizations and interpretations
# - ✅ Save your notebook!
#
# ---
#
# ### 📚 Additional Resources
#
# - [Scikit-learn Documentation](https://scikit-learn.org/)
# - [TF-IDF Explained](https://en.wikipedia.org/wiki/Tf%E2%80%93idf)
# - [Confusion Matrix Guide](https://en.wikipedia.org/wiki/Confusion_matrix)
# - [Text Preprocessing Best Practices](https://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction)
#
# ---
#
# *Good luck with your project! 🚀*
